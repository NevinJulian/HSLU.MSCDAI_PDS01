# %%
print('hello world')
print('-' * 3)
a = 3
b = 5 - a
print('hello world\n' * b)
# Out:
# hello world
# ---
# hello world
# hello world

# %%
x = 99
type(x)          # <class 'int'>
print(type(x))
x = "text"
type(x)          # <class 'str'>
print(type(x))

a = [1, 2]
b = a            # b is a second name for the same list
b.append(3)
a                # [1, 2, 3]
# Out:
# <class 'int'>
# <class 'str'>
# [1, 2, 3]
